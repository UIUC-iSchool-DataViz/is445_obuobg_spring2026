# %% [markdown]
# # In Class Notebook, Week 03

# %% [markdown]
# You can access this notebook in near-real time by going here (be sure to refresh page!): https://github.com/UIUC-iSchool-DataViz/is445_obuobg_spring2026/blob/main/week03/inClass_week03.ipynb
#
# For plain rendering, past URL into the nbviewer interface (note, sometimes takes a refresh):
#
# https://kokes.github.io/nbviewer.js/viewer.html

# %%
import matplotlib.pyplot as plt # SHIFT+RETURN
import PIL.Image as Image # only import Image function

# %%
#!wget https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/stitch_reworked.png

# %%
# !ls -- use this if you are on Mac/PL
# !dir -- on Windows (I think!)

# %%
im = Image.open('stitch_reworked.png')

# %%
type(im)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
import numpy as np

# %%
im_data = np.array(im)

# %%
im_data.shape # 483 rows, 430 columns, 4 color channels -- R=red, G=green, B=blue, A=alpha/opacity
# Out:
# (483, 430, 4)

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data[:,:,0]) # [:,:,0] == all pixels in rows, columns in the Red color channel
plt.show()

# %%
im_data[:,:,0].shape
# Out:
# (483, 430)

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data[:,:,0].flatten()) # [:,:,0] == all pixels in rows, columns in the Red color channel
# instead of passing a 2D thing, we are passing a 1d-thing
plt.show()

# %%
im_data[:,:,0].flatten().shape
# Out:
# (207690,)

# %%
np.unique(im_data[:,:,0])
# Out:
# array([  0, 126, 255], dtype=uint8)

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data[:,:,0].flatten(), bins=256) # [:,:,0] == all pixels in rows, columns in the Red color channel
# instead of passing a 2D thing, we are passing a 1d-thing
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data[:,:,0].flatten(), bins=256, color='red') # [:,:,0] == all pixels in rows, columns in the Red color channel
ax.set_xlabel('Red channel bins')
ax.set_ylabel('# of pixels per bin')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data[:,:,0].flatten(), bins=256, color='red') # [:,:,0] == Red channel
ax.hist(im_data[:,:,1].flatten(), bins=256, color='green') # [:,:,1] == Green channel
ax.set_xlabel('Channel bins')
ax.set_ylabel('# of pixels per bin')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data[:,:,0].flatten(), bins=256, color='red') # [:,:,0] == Red channel
ax.hist(im_data[:,:,1].flatten(), bins=256, color='green') # [:,:,1] == Green channel
ax.hist(im_data[:,:,2].flatten(), bins=256, color='blue') # [:,:,2] == Blue channel
ax.hist(im_data[:,:,3].flatten(), bins=256, color='gray') # [:,:,3] == Alpha/opacity channel
ax.set_xlabel('Channel bins')
ax.set_ylabel('# of pixels per bin')
plt.show()

# %%
fig, ax = plt.subplots(4,1, figsize=(10,8))

# %%
ax[0]
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(4, 1, figsize=(10,8))
ax[0].hist(im_data[:,:,0].flatten(), bins=256, color='red') # [:,:,0] == Red channel
ax[1].hist(im_data[:,:,1].flatten(), bins=256, color='green') # [:,:,1] == Green channel
ax[2].hist(im_data[:,:,2].flatten(), bins=256, color='blue') # [:,:,2] == Blue channel
ax[3].hist(im_data[:,:,3].flatten(), bins=256, color='gray') # [:,:,3] == Alpha/opacity channel
# ax.set_xlabel('Channel bins')
# ax.set_ylabel('# of pixels per bin')
plt.show()

# %%
#im

# %%
fig, ax = plt.subplots(4, 1, figsize=(10,8))
ax[0].hist(im_data[:,:,0].flatten(), bins=256, color='red') # [:,:,0] == Red channel
ax[1].hist(im_data[:,:,1].flatten(), bins=256, color='green') # [:,:,1] == Green channel
ax[2].hist(im_data[:,:,2].flatten(), bins=256, color='blue') # [:,:,2] == Blue channel
ax[3].hist(im_data[:,:,3].flatten(), bins=256, color='gray') # [:,:,3] == Alpha/opacity channel
ax[0].set_xlabel('Red Channel bins')
ax[1].set_xlabel('Green Channel bins')
ax[2].set_xlabel('Blue Channel bins')
ax[3].set_xlabel('Alpha Channel bins')
# y-axis will be same for all --> for loop
for a in ax:
    a.set_ylabel('# of pixels per bin')

fig.tight_layout() # fits all plot elements in a small space without overlapping
plt.show()

# %%
fig, ax = plt.subplots(5, 1, figsize=(10,8))
ax[0].hist(im_data[:,:,0].flatten(), bins=256, color='red') # [:,:,0] == Red channel
ax[1].hist(im_data[:,:,1].flatten(), bins=256, color='green') # [:,:,1] == Green channel
ax[2].hist(im_data[:,:,2].flatten(), bins=256, color='blue') # [:,:,2] == Blue channel
ax[3].hist(im_data[:,:,3].flatten(), bins=256, color='gray') # [:,:,3] == Alpha/opacity channel
ax[0].set_xlabel('Red Channel bins')
ax[1].set_xlabel('Green Channel bins')
ax[2].set_xlabel('Blue Channel bins')
ax[3].set_xlabel('Alpha Channel bins')
# y-axis will be same for all --> for loop
for a in ax[:-1]: # make sure don't add to image itself
    a.set_ylabel('# of pixels per bin')

ax[4].imshow(im_data)

fig.tight_layout() # fits all plot elements in a small space without overlapping
plt.show()

# %% [markdown]
# ## More complex image
#
# (I did `ESC+m` to get this cell in markdown)
