# %% [markdown]
# # In Class Notebook, Week 01

# %% [markdown]
# The URL of this notebook: https://github.com/UIUC-iSchool-DataViz/is445_obuobg_spring2026/blob/main/week01/inClass_week01.ipynb
#
# For plain rendering, past URL into the nbviewer interface (note, sometimes takes a refresh):
#
# https://kokes.github.io/nbviewer.js/viewer.html
